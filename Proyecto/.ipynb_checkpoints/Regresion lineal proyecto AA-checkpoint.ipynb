# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# Cargamos los datos
datos = pd.read_csv("water_potability.csv")
means = datos.mean(axis=0, skipna=True)

for e in datos:
    datos[e] = datos[e].fillna(means[e])
    
Y = datos.iloc[:,-1]
Y = np.array(Y)
datos = datos.iloc[:,:-1]
datos
#Hasta aqui datos cargados y sustituimos los nan por la media
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
def normalize(X):
    mean = np.mean(X, axis=0)
    X_mean = X - mean
    std = np.std(X, axis=0)
    X_norm = X_mean / std 
    return X_norm

#definimos funciones de normalizacion
X = np.asarray(datos)
X_norm = normalize(X)

filas = np.shape(X)[0]

#XO = np.hstack([np.ones([filas,1]),X_norm])
X1 = np.hstack([np.ones([filas,1]),X])

columnas = np.shape(XO)[1]

# %%
train_size = 0.7
validation_size = 0.1
test_size = 0.2

validation = validation_size / (test_size + validation_size)
xn_train, xn_test, y_train, y_test = train_test_split(XO, Y, train_size=train_size)
xn_val, xn_test, y_val, y_test = train_test_split(xn_test, y_test, train_size=validation)

x_train, x_test, y_train, y_test = train_test_split(X1, Y, train_size=train_size)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, train_size=validation)

print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (2293, 10) (327, 10) (656, 10)

# %%
#datos = datos puros en pandas
#X = datos pasados a numpy
#X1 = datos numpy con columna de 1
#X_norm = datos normalizados
#XO = datos normalizados con columna de 1

#x_train = conjunto de entrenamiento con columna de 1
#x_val = conjunto de validacion con columna de 1
#X_test = conjunto de test con columna de 1
#xn_train = x_train normalizado
#xn_val = x_val normalizado
#Xn_test = x_test normalizado

#Y = array de resultados
#y_train = las ys correspondientes al conjunto de entrenamiento
#y_val = las ys correspondientes al conjunto de validacion
#y_test = las ys correspondientes al conjunto de test

# %% [markdown]
# # Regresion lineal

# %%
from scipy.optimize import minimize

def hip(X, theta):
    return np.dot(X, theta)

def cost(theta, X, Y, reg):
    filas = np.shape(X)[0]
    m = np.shape(X)[0]
    return (1 / (2 * filas)) * np.sum(((hip(X, theta) - Y) ** 2)) + ((reg / (2 * filas)) * np.sum(theta[1:] ** 2))          

def gradient(theta, X, Y, reg):
    filas = np.shape(X)[0]
    gradiente = (1 / filas) * np.dot((hip(X, theta) - Y), X)
    result = np.zeros(np.shape(X)[1])
    result[0] = gradiente[0]
    result[1:] = gradiente[1:] + (theta[1:] * (reg / filas))
    return  result

# Ecuacion normal
def ecuacion_normal(X, Y):
    filas = np.shape(X)[0]
    th = np.linalg.inv(np.transpose(X).dot(X)).dot(np.transpose(X)).dot(Y)
    return th

def porcentaje(X, Y, thetas):
    ok = 0
    i = 0
    for h in hip(X, thetas):
        if h >= 0.5:
            if Y[i] == 1.0:
                ok +=1
        else:
            if Y[i] == 0.0:
                ok +=1
        i +=1
    return (ok / np.shape(X)[0])

# %% [markdown]
# Vamos a hacer la regresion lineal con la ecuacion normal

# %%
thetas = ecuacion_normal(x_train, y_train)
print(porcentaje(x_test,y_test, thetas))
# Out:
# 0.600609756097561

# %% [markdown]
# Regresion lineal descenso de gradiente

# %%
lamdas = [0, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10, 100]
for reg in lamdas:
    theta = np.array([1] * (xn_train.shape[1]))
    theta_opt = minimize(fun=cost, x0=theta, args=(xn_train, y_train, reg), jac=gradient).x
    print(porcentaje(xn_test, y_test, theta_opt))
# Out:
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561
# 0.600609756097561

# %%
def lamdas_error(n, training_y, crossval_y):
    plt.plot(n, training_y, label='Training error')
    plt.plot(n, crossval_y, label='Cross Validation error')
    plt.xlabel('Lambda')
    plt.ylabel('Error')
    plt.title('Errors for different lamda values')
    plt.legend()
    plt.show()

lamdas = [0, 0.001, 0.003, 0.01, 0.03, 0.1, 0.3, 1, 3, 10, 1000, 100000, 10000000]
X_error = []
Val_error = []
Total_error = []
#   Seleccionamos el lambda que da menor error entre los ejemplos de entrenamiento
# y los datos de validacion
for e in lamdas:
    theta_opt = minimize(fun=cost, x0=theta, args=(xn_train, y_train, e), jac=gradient).x
    Xe = cost(theta_opt, xn_train, y_train, e)
    Ve = cost(theta_opt, xn_val, y_val, e)
    X_error.append(Xe)
    Val_error.append(Ve)
    Total_error.append(np.abs(Xe - Ve))
    print('lamda: ', e,' Error: ', Xe,'Validation error: ', Ve)
 
i = np.argmin(Total_error)
min_lambda = lamdas[i];
print("Menor lambda: ", min_lambda) 

lamdas_error(lamdas, X_error, Val_error)
# Out:
# lamda:  0  Error:  0.11791162097945866 Validation error:  0.1206566277698666
# lamda:  0.001  Error:  0.11791162118679434 Validation error:  0.12065662910011705
# lamda:  0.003  Error:  0.1179116216014652 Validation error:  0.12065663176061142
# lamda:  0.01  Error:  0.11791162305280756 Validation error:  0.12065664107227245
# lamda:  0.03  Error:  0.11791162719945174 Validation error:  0.12065666767642509
# lamda:  0.1  Error:  0.11791164171214316 Validation error:  0.12065676078403977
# lamda:  0.3  Error:  0.117911683172149 Validation error:  0.1206570267464972
# lamda:  1  Error:  0.11791182822588081 Validation error:  0.12065795692375075
# lamda:  3  Error:  0.11791224218324939 Validation error:  0.12066060865927164
# lamda:  10  Error:  0.11791368543595775 Validation error:  0.12066982120869409
# lamda:  1000  Error:  0.11805664133036307 Validation error:  0.12132851796176918
# lamda:  100000  Error:  0.11838607471929019 Validation error:  0.12094424536414239
# ...

# %% [markdown]
# # Kernel reshulon

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

#def best_C_sigma(X, y_test, X_test, y_test):
values = np.linspace(0.1,10000, 100, dtype=float)
best_C = 0
best_sigma = 0
best_acc = 0
for C in values:
    for sigma in values:
        svm = SVC(kernel='rbf', C=C, gamma=1 / (2 * sigma**2))
        svm.fit(xn_train, y_train)
        acc = accuracy_score(y_val, svm.predict(xn_val))
        print(C,sigma, "acuraccy: ", acc)
        if acc > best_acc:
            best_C = C
            best_sigma = sigma
            best_acc = acc
# Out:
# 0.1 0.1 acuraccy:  0.5840978593272171
# 0.1 101.1090909090909 acuraccy:  0.5840978593272171
# 0.1 202.1181818181818 acuraccy:  0.5840978593272171
# 0.1 303.1272727272727 acuraccy:  0.5840978593272171
# 0.1 404.1363636363636 acuraccy:  0.5840978593272171
# 0.1 505.1454545454545 acuraccy:  0.5840978593272171
# 0.1 606.1545454545454 acuraccy:  0.5840978593272171
# 0.1 707.1636363636363 acuraccy:  0.5840978593272171
# 0.1 808.1727272727272 acuraccy:  0.5840978593272171
# 0.1 909.1818181818181 acuraccy:  0.5840978593272171
# 0.1 1010.190909090909 acuraccy:  0.5840978593272171
# 0.1 1111.1999999999998 acuraccy:  0.5840978593272171
# 0.1 1212.2090909090907 acuraccy:  0.5840978593272171
# 0.1 1313.2181818181816 acuraccy:  0.5840978593272171
# 0.1 1414.2272727272725 acuraccy:  0.5840978593272171
# 0.1 1515.2363636363634 acuraccy:  0.5840978593272171
# 0.1 1616.2454545454543 acuraccy:  0.5840978593272171
# 0.1 1717.2545454545452 acuraccy:  0.5840978593272171
# ...

# %%
print(best_acc, best_C, best_sigma)
# Out:
# 0.5840978593272171 10000.0 10000.0

# %%
svm = SVC(kernel='rbf', C=30, gamma=1 / (2 * 30**2))
svm.fit(xn_train, y_train)
acc = accuracy_score(y_test, svm.predict(xn_test))
acc
# Out:
# 0.614329268292683
